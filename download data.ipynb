# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
 
 
spark = SparkSession.builder.getOrCreate()
 
 
spark.conf.set(
    "fs.azure.account.key.airbnbpro.dfs.core.windows.net",
    "lVruAoAQKhAWULpLEB3Av5hkYRO/t8huLF/Dw3ADus1RwER1V1YBnfRHST9FYKkcWTtcoecSeQ+p+AStOwPu+g=="
)

# %%
import requests
import gzip
import shutil
from pathlib import Path
import time
import random
import pandas as pd
from bs4 import BeautifulSoup
import re


class AirbnbScraper:
    def __init__(self):
        self.local_tmp_dir = Path("/tmp/airbnb_downloads")
        self.local_tmp_dir.mkdir(parents=True, exist_ok=True)
        self.output_dir = "abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data"
        self.session = requests.Session()
        self.session.headers.update(
            {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
                "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
                "Accept-Language": "en-US,en;q=0.5",
            }
        )


    def scrape_city_urls(self):
        print("🌐 Scraping Inside Airbnb website...")
        try:
            response = self.session.get(
                "https://insideairbnb.com/get-the-data/", timeout=30
            )
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            cities_data = {}
            print("   🔍 Searching for data links...")
            all_links = soup.find_all("a", href=True)
            for link in all_links:
                href = link["href"]
                if "data.insideairbnb.com" in href and "listings.csv.gz" in href:
                    city_data = self.extract_city_from_url(href, link)
                    if city_data and city_data["city_name"] not in cities_data:
                        cities_data[city_data["city_name"]] = city_data
                        print(f"   ✅ Found: {city_data['display_name']}")
            print("   🔍 Searching in page content...")
            text_content = soup.get_text()
            url_pattern = r'https://data\.insideairbnb\.com/[^\s<>"]+?listings\.csv\.gz'
            url_matches = re.findall(url_pattern, text_content)
            for url in url_matches:
                city_data = self.extract_city_from_url(url, None)
                if city_data and city_data["city_name"] not in cities_data:
                    cities_data[city_data["city_name"]] = city_data
                    print(f"   ✅ Found: {city_data['display_name']}")
            print(f"🎯 Found {len(cities_data)} cities with listings data")
            return cities_data
        except Exception as e:
            print(f"❌ Error scraping: {e}")
            return self.get_fallback_urls()


    def extract_city_from_url(self, url, link_element):
        try:
            parts = url.split("/")
            if len(parts) >= 8:
                country = parts[3]
                city = parts[5]
                date = parts[6]
                city_clean = self.clean_filename(city)
                if link_element and link_element.get_text().strip():
                    display_name = link_element.get_text().strip()
                else:
                    display_name = f"{city.replace('-', ' ').title()}, {country.replace('-', ' ').title()}"
                return {
                    "city_name": city_clean,
                    "country_name": country,
                    "display_name": display_name,
                    "listings_url": url,
                    "date": date,
                }
            return None
        except Exception as e:
            print(f"   Error parsing URL {url}: {e}")
            return None


    def clean_filename(self, name):
        clean = re.sub(r"[^a-zA-Z0-9_]", "_", name)
        clean = re.sub(r"_+", "_", clean)
        clean = clean.strip("_")
        return clean.lower()


    def get_fallback_urls(self):
        print("🔄 Using fallback URLs...")
        fallback_cities = {
            "berlin": {
                "city_name": "berlin",
                "country_name": "germany",
                "display_name": "Berlin, Germany",
                "listings_url": "https://data.insideairbnb.com/germany/be/berlin/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
            "london": {
                "city_name": "london",
                "country_name": "uk",
                "display_name": "London, UK",
                "listings_url": "https://data.insideairbnb.com/united-kingdom/england/london/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
            "paris": {
                "city_name": "paris",
                "country_name": "france",
                "display_name": "Paris, France",
                "listings_url": "https://data.insideairbnb.com/france/ile-de-france/paris/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
            "new_york": {
                "city_name": "new_york",
                "country_name": "usa",
                "display_name": "New York, USA",
                "listings_url": "https://data.insideairbnb.com/united-states/ny/new-york-city/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
            "los_angeles": {
                "city_name": "los_angeles",
                "country_name": "usa",
                "display_name": "Los Angeles, USA",
                "listings_url": "https://data.insideairbnb.com/united-states/ca/los-angeles/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
            "tokyo": {
                "city_name": "tokyo",
                "country_name": "japan",
                "display_name": "Tokyo, Japan",
                "listings_url": "https://data.insideairbnb.com/japan/kant%C5%8D/tokyo/2025-09-23/data/listings.csv.gz",
                "date": "2025-09-23",
            },
        }
        print(f"🎯 Loaded {len(fallback_cities)} fallback cities")
        return fallback_cities


    def download_city_listings(self, city_data):
        try:
            city_name = city_data["city_name"]
            listings_url = city_data["listings_url"]
            display_name = city_data["display_name"]
            date = city_data["date"]

            filename = f"{city_name}.csv"
            local_output_path = self.local_tmp_dir / filename

            print(f"\n📥 Downloading: {display_name}")
            print(f"    Date: {date}")
            print(f"    URL: {listings_url}")

            if self.download_and_extract_gz(listings_url, local_output_path):
                print(f"✅ Success: {filename}")

                # Read with pandas and add city column
                print("    📊 Reading CSV with pandas...")
                df_pd = pd.read_csv(local_output_path)
                df_pd["city"] = city_name
                print(f"    📈 Loaded {len(df_pd)} rows")

                # Convert to Spark DataFrame
                print("    ⚡ Converting to Spark DataFrame...")
                df_spark = spark.createDataFrame(df_pd)

                # Write to temporary directory first
                temp_dir = f"{self.output_dir}/temp_{city_name}"
                final_path = f"{self.output_dir}/{city_name}.csv"
                
                print("    💾 Writing to temporary directory...")
                # Write as single CSV with proper options
                df_spark.coalesce(1).write.mode("overwrite") \
                    .option("header", True) \
                    .option("quote", '"') \
                    .option("escape", '"') \
                    .option("quoteAll", True) \
                    .csv(temp_dir)
                
                # Find the part file and move it to final location
                print(f"    📦 Finding part file in temp directory...")
                part_files = dbutils.fs.ls(temp_dir)
                csv_part_file = [f for f in part_files if f.name.startswith("part-") and f.name.endswith(".csv")]
                
                if not csv_part_file:
                    print(f"    ❌ No part file found in {temp_dir}")
                    # List what's actually there for debugging
                    print("    Files found:")
                    for f in part_files:
                        print(f"      - {f.name}")
                    return False
                
                part_file = csv_part_file[0]
                print(f"    ✅ Found: {part_file.name}")
                
                # Copy the part file to final destination with clean name
                print(f"    📋 Copying to final location: {final_path}")
                dbutils.fs.cp(part_file.path, final_path)
                
                # Clean up temporary directory
                print(f"    🗑️  Cleaning up temp directory...")
                dbutils.fs.rm(temp_dir, recurse=True)

                print(f"    ✅ Saved to: {final_path}")
                
                # Verify the file exists
                try:
                    file_info = dbutils.fs.ls(final_path)
                    print(f"    ✓ Verified: File exists ({file_info[0].size / (1024*1024):.2f} MB)")
                except:
                    print(f"    ⚠️  Warning: Could not verify file")
                
                return True
            else:
                print(f"❌ Failed: {city_name}")
                return False

        except Exception as e:
            print(f"❌ Error with {city_name}: {e}")
            import traceback
            traceback.print_exc()
            
            # Cleanup temp directory if it exists
            try:
                temp_dir = f"{self.output_dir}/temp_{city_name}"
                dbutils.fs.rm(temp_dir, recurse=True)
                print(f"    🗑️  Cleaned up temp directory after error")
            except:
                pass
            
            return False


    def download_and_extract_gz(self, url, output_path):
        try:
            delay = random.uniform(3, 6)
            print(f"    ⏳ Waiting {delay:.1f} seconds...")
            time.sleep(delay)
            print("    🌐 Sending request...")
            with requests.Session() as download_session:
                download_session.headers.update(
                    {
                        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
                        "Referer": "https://insideairbnb.com/",
                        "Accept": "*/*",
                    }
                )
                response = download_session.get(url, stream=True, timeout=60)
                if response.status_code != 200:
                    print(f"    ❌ HTTP {response.status_code}: {response.reason}")
                    return False
                total_size = int(response.headers.get("content-length", 0))
                downloaded_size = 0
                file_size_mb = (
                    total_size / (1024 * 1024) if total_size > 0 else "unknown"
                )
                print(f"    📦 Downloading file ({file_size_mb:.1f} MB)...")
                temp_gz_path = self.local_tmp_dir / "temp_listings.gz"
                with open(temp_gz_path, "wb") as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        if chunk:
                            f.write(chunk)
                            downloaded_size += len(chunk)
                            if total_size > 0:
                                percent = (downloaded_size / total_size) * 100
                                print(f"    Progress: {percent:.1f}%", end="\r")
                print("\n    ✅ Download completed!")
                print("    📦 Extracting file...")
                with gzip.open(temp_gz_path, "rb") as f_in:
                    with open(output_path, "wb") as f_out:
                        shutil.copyfileobj(f_in, f_out)
                temp_gz_path.unlink()
                if output_path.exists():
                    file_size = output_path.stat().st_size / (1024 * 1024)
                    print(f"    💾 Saved to: {output_path}")
                    print(f"    📊 File size: {file_size:.2f} MB")
                    return True
                return False
        except Exception as e:
            print(f"    ❌ Download error: {e}")
            temp_gz_path = self.local_tmp_dir / "temp_listings.gz"
            if temp_gz_path.exists():
                temp_gz_path.unlink()
            return False


def main():
    scraper = AirbnbScraper()
    print("🏠 Airbnb Data Scraper")
    print(f"📂 Output: {scraper.output_dir}")
    print("🔍 Scanning website for city data...\n")
    
    cities_data = scraper.scrape_city_urls()
    
    if not cities_data:
        print("❌ No cities found.")
        return
    
    print("\n📋 Available cities:")
    city_list = list(cities_data.items())
    for i, (city_name, city_info) in enumerate(city_list, 1):
        print(f"  {i}. {city_info['display_name']} ({city_info['date']})")
    print(f"  {len(city_list) + 1}. 🚀 DOWNLOAD ALL CITIES")
    
    try:
        choice = input("\n👉 Choose cities (e.g., 1 or 1,2,3 or all): ").strip()
        successful_downloads = 0
        total_attempts = 0
        downloaded_files = []
        
        if choice == str(len(city_list) + 1) or choice.lower() == "all":  # DOWNLOAD ALL
            print(f"\n🚀 Downloading ALL {len(city_list)} cities...")
            for city_name, city_data in city_list:
                total_attempts += 1
                if scraper.download_city_listings(city_data):
                    successful_downloads += 1
                    downloaded_files.append(f"{city_name}.csv")
                time.sleep(random.uniform(5, 8))
        else:  # Specific cities
            choices = [int(x.strip()) for x in choice.split(",")]
            for choice_num in choices:
                if 1 <= choice_num <= len(city_list):
                    city_name, city_data = city_list[choice_num - 1]
                    total_attempts += 1
                    if scraper.download_city_listings(city_data):
                        successful_downloads += 1
                        downloaded_files.append(f"{city_name}.csv")
                    time.sleep(random.uniform(5, 8))
                else:
                    print(f"❌ Invalid choice: {choice_num}")
        
        print(f"\n{'=' * 50}")
        print("📊 DOWNLOAD SUMMARY")
        print(f"{'=' * 50}")
        print(f"✅ Successful: {successful_downloads}/{total_attempts}")
        print(f"📂 Location: {scraper.output_dir}")
        if downloaded_files:
            print("📄 Files created:")
            for file in downloaded_files:
                print(f"   • {file}")
        print(f"{'=' * 50}")
        
    except KeyboardInterrupt:
        print("\n\n⚠️  Download interrupted by user")
    except Exception as e:
        print(f"❌ Error: {e}")
        import traceback
        traceback.print_exc()


if __name__ == "__main__":
    main()
# Out:
# 🏠 Airbnb Data Scraper
# 📂 Output: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data
# 🔍 Scanning website for city data...
#
# 🌐 Scraping Inside Airbnb website...
#    🔍 Searching for data links...
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    ✅ Found: listings.csv.gz
#    🔍 Searching in page content...
# 🎯 Found 118 cities with listings data
#
# 📋 Available cities:
#   1. listings.csv.gz (2025-10-05)
#   2. listings.csv.gz (2025-09-11)
#   3. listings.csv.gz (2025-06-25)
#   4. listings.csv.gz (2025-06-17)
#   5. listings.csv.gz (2025-09-26)
#   6. listings.csv.gz (2025-06-13)
#   7. listings.csv.gz (2025-09-26)
#   8. listings.csv.gz (2025-09-14)
#   9. listings.csv.gz (2025-09-27)
#   10. listings.csv.gz (2025-09-28)
#   11. listings.csv.gz (2024-12-27)
#   12. listings.csv.gz (2025-09-28)
#   13. listings.csv.gz (2025-06-28)
#   14. listings.csv.gz (2025-09-23)
#   15. listings.csv.gz (2025-09-22)
#   16. listings.csv.gz (2025-06-15)
#   17. listings.csv.gz (2025-09-23)
#   18. listings.csv.gz (2025-10-17)
#   19. listings.csv.gz (2025-10-07)
#   20. listings.csv.gz (2025-09-26)
#   21. listings.csv.gz (2025-09-26)
#   22. listings.csv.gz (2025-06-21)
#   23. listings.csv.gz (2025-09-25)
#   24. listings.csv.gz (2025-01-29)
#   25. listings.csv.gz (2025-09-28)
#   26. listings.csv.gz (2025-09-28)
#   27. listings.csv.gz (2025-06-17)
#   28. listings.csv.gz (2025-09-23)
#   29. listings.csv.gz (2025-09-26)
#   30. listings.csv.gz (2025-06-27)
#   31. listings.csv.gz (2025-09-28)
#   32. listings.csv.gz (2025-08-19)
#   33. listings.csv.gz (2025-09-29)
#   34. listings.csv.gz (2025-09-16)
#   35. listings.csv.gz (2025-09-21)
#   36. listings.csv.gz (2025-06-28)
#   37. listings.csv.gz (2025-06-19)
#   38. listings.csv.gz (2025-09-16)
#   39. listings.csv.gz (2025-09-28)
#   40. listings.csv.gz (2025-09-26)
#   41. listings.csv.gz (2025-06-28)
#   42. listings.csv.gz (2025-09-26)
#   43. listings.csv.gz (2025-09-16)
#   44. listings.csv.gz (2025-06-21)
#   45. listings.csv.gz (2025-09-29)
#   46. listings.csv.gz (2025-09-25)
#   47. listings.csv.gz (2025-09-21)
#   48. listings.csv.gz (2025-09-14)
#   49. listings.csv.gz (2025-09-01)
#   50. listings.csv.gz (2025-06-15)
#   51. listings.csv.gz (2025-09-14)
#   52. listings.csv.gz (2025-06-29)
#   53. listings.csv.gz (2025-09-21)
#   54. listings.csv.gz (2025-09-12)
#   55. listings.csv.gz (2025-09-30)
#   56. listings.csv.gz (2025-06-25)
#   57. listings.csv.gz (2025-10-17)
#   58. listings.csv.gz (2025-06-19)
#   59. listings.csv.gz (2025-09-18)
#   60. listings.csv.gz (2025-06-15)
#   61. listings.csv.gz (2025-09-27)
#   62. listings.csv.gz (2025-06-19)
#   63. listings.csv.gz (2025-09-23)
#   64. listings.csv.gz (2025-06-25)
#   65. listings.csv.gz (2025-09-11)
#   66. listings.csv.gz (2025-10-01)
#   67. listings.csv.gz (2025-09-30)
#   68. listings.csv.gz (2025-06-17)
#   69. listings.csv.gz (2025-09-25)
#   70. listings.csv.gz (2025-09-29)
#   71. listings.csv.gz (2025-06-17)
#   72. listings.csv.gz (2025-06-29)
#   73. listings.csv.gz (2025-09-12)
#   74. listings.csv.gz (2025-06-15)
#   75. listings.csv.gz (2025-09-06)
#   76. listings.csv.gz (2025-09-21)
#   77. listings.csv.gz (2025-06-20)
#   78. listings.csv.gz (2025-09-29)
#   79. listings.csv.gz (2025-10-17)
#   80. listings.csv.gz (2025-09-30)
#   81. listings.csv.gz (2025-09-29)
#   82. listings.csv.gz (2025-09-26)
#   83. listings.csv.gz (2025-09-25)
#   84. listings.csv.gz (2025-09-14)
#   85. listings.csv.gz (2025-09-25)
#   86. listings.csv.gz (2025-09-25)
#   87. listings.csv.gz (2025-09-25)
#   88. listings.csv.gz (2025-09-01)
#   89. listings.csv.gz (2025-09-25)
#   90. listings.csv.gz (2025-09-25)
#   91. listings.csv.gz (2025-06-28)
#   92. listings.csv.gz (2024-12-27)
#   93. listings.csv.gz (2025-09-25)
#   94. listings.csv.gz (2025-09-29)
#   95. listings.csv.gz (2025-09-29)
#   96. listings.csv.gz (2025-09-28)
#   97. listings.csv.gz (2025-09-23)
#   98. listings.csv.gz (2025-09-29)
#   99. listings.csv.gz (2025-09-30)
#   100. listings.csv.gz (2025-09-12)
#   101. listings.csv.gz (2025-06-29)
#   102. listings.csv.gz (2025-09-11)
#   103. listings.csv.gz (2025-09-25)
#   104. listings.csv.gz (2025-09-26)
#   105. listings.csv.gz (2025-06-27)
#   106. listings.csv.gz (2025-10-07)
#   107. listings.csv.gz (2025-06-29)
#   108. listings.csv.gz (2025-06-21)
#   109. listings.csv.gz (2025-09-23)
#   110. listings.csv.gz (2025-10-17)
#   111. listings.csv.gz (2025-10-05)
#   112. listings.csv.gz (2025-09-11)
#   113. listings.csv.gz (2025-09-29)
#   114. listings.csv.gz (2025-09-14)
#   115. listings.csv.gz (2025-06-17)
#   116. listings.csv.gz (2025-06-23)
#   117. listings.csv.gz (2025-06-15)
#   118. listings.csv.gz (2025-06-27)
#   119. 🚀 DOWNLOAD ALL CITIES
# 👉 Choose cities (e.g., 1 or 1,2,3 or all):  119
# 🚀 Downloading ALL 118 cities...
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-05
#     URL: https://data.insideairbnb.com/united-states/ny/albany/2025-10-05/data/listings.csv.gz
#     ⏳ Waiting 3.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/albany.csv
#     📊 File size: 1.03 MB
# ✅ Success: albany.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 461 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-5827831355443759960-a800179c-a10a-42e0-b4d5-217fcc96ec27-0-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/albany.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/albany.csv
#     ✓ Verified: File exists (1.10 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-11
#     URL: https://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2025-09-11/data/listings.csv.gz
#     ⏳ Waiting 6.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (5.7 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/amsterdam.csv
#     📊 File size: 22.82 MB
# ✅ Success: amsterdam.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 10480 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4150526646526742291-13ba8a65-dc14-456f-b08c-638244778520-8-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/amsterdam.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/amsterdam.csv
#     ✓ Verified: File exists (24.54 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-25
#     URL: https://data.insideairbnb.com/belgium/vlg/antwerp/2025-06-25/data/listings.csv.gz
#     ⏳ Waiting 3.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/antwerp.csv
#     📊 File size: 5.59 MB
# ✅ Success: antwerp.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 2654 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-5664609841179778702-f8efe5eb-4183-4f67-841f-b1251bbeb976-16-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/antwerp.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/antwerp.csv
#     ✓ Verified: File exists (6.03 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-17
#     URL: https://data.insideairbnb.com/united-states/nc/asheville/2025-06-17/data/listings.csv.gz
#     ⏳ Waiting 3.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.7 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/asheville.csv
#     📊 File size: 7.33 MB
# ✅ Success: asheville.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 2876 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-5759137685035859947-b114f26c-1eda-40b5-b4de-76cd94e4f157-24-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/asheville.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/asheville.csv
#     ✓ Verified: File exists (7.78 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/greece/attica/athens/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 4.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (8.1 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/athens.csv
#     📊 File size: 35.68 MB
# ✅ Success: athens.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 15584 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-8463737133515315392-235d5844-c0bc-4317-82ee-3f916900060c-32-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/athens.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/athens.csv
#     ✓ Verified: File exists (38.25 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-13
#     URL: https://data.insideairbnb.com/united-states/tx/austin/2025-06-13/data/listings.csv.gz
#     ⏳ Waiting 3.7 seconds...
#     🌐 Sending request...
#     📦 Downloading file (8.4 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/austin.csv
#     📊 File size: 35.61 MB
# ✅ Success: austin.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 15187 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-8407971798130250223-8e01ba9e-bc50-47df-a027-347384d6d549-40-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/austin.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/austin.csv
#     ✓ Verified: File exists (37.96 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/thailand/central-thailand/bangkok/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 4.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (14.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bangkok.csv
#     📊 File size: 58.64 MB
# ✅ Success: bangkok.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 28806 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1014006844446180436-f09227c4-7d79-4973-901f-7fe8a38228a3-48-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bangkok.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bangkok.csv
#     ✓ Verified: File exists (63.38 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-14
#     URL: https://data.insideairbnb.com/spain/catalonia/barcelona/2025-09-14/data/listings.csv.gz
#     ⏳ Waiting 3.3 seconds...
#     🌐 Sending request...
#     📦 Downloading file (9.3 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/barcelona.csv
#     📊 File size: 41.19 MB
# ✅ Success: barcelona.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 19410 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1197860326987703787-ea7c74bf-4e71-4a0b-bc0a-d171faf0b28c-56-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barcelona.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barcelona.csv
#     ✓ Verified: File exists (44.41 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-27
#     URL: https://data.insideairbnb.com/australia/sa/barossa-valley/2025-09-27/data/listings.csv.gz
#     ⏳ Waiting 4.8 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/barossa_valley.csv
#     📊 File size: 0.82 MB
# ✅ Success: barossa_valley.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 353 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-2805256569956603879-517ce2e9-bd12-409c-9ec5-ce356e069cf9-64-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barossa_valley.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barossa_valley.csv
#     ✓ Verified: File exists (0.88 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-28
#     URL: https://data.insideairbnb.com/australia/vic/barwon-south-west-vic/2025-09-28/data/listings.csv.gz
#     ⏳ Waiting 3.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.9 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/barwon_south_west_vic.csv
#     📊 File size: 16.73 MB
# ✅ Success: barwon_south_west_vic.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 7280 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-2762717822717768681-8958a206-76cf-40d2-9e16-a399770b6559-72-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barwon_south_west_vic.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/barwon_south_west_vic.csv
#     ✓ Verified: File exists (18.04 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2024-12-27
#     URL: https://data.insideairbnb.com/china/beijing/beijing/2024-12-27/data/listings.csv.gz
#     ⏳ Waiting 5.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/beijing.csv
#     📊 File size: 0.00 MB
# ✅ Success: beijing.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 0 rows
#     ⚡ Converting to Spark DataFrame...
# ❌ Error with beijing: [CANNOT_INFER_EMPTY_SCHEMA] Can not infer schema from an empty dataset.
# Traceback (most recent call last):
#   File "/home/spark-a2a45b4a-1ba9-462d-90c6-22/.ipykernel/2534/command-6159821325050266-1257879295", line 168, in download_city_listings
#     df_spark = spark.createDataFrame(df_pd)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/databricks/spark/python/pyspark/sql/connect/session.py", line 601, in createDataFrame
#     raise PySparkValueError(
# pyspark.errors.exceptions.base.PySparkValueError: [CANNOT_INFER_EMPTY_SCHEMA] Can not infer schema from an empty dataset.
#     🗑️  Cleaned up temp directory after error
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-28
#     URL: https://data.insideairbnb.com/belize/bz/belize/2025-09-28/data/listings.csv.gz
#     ⏳ Waiting 4.8 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.6 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/belize.csv
#     📊 File size: 7.99 MB
# ✅ Success: belize.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 3581 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4760056778397472358-f8cc3b4d-d3e3-4873-baa7-54bf8ce3b1c8-81-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/belize.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/belize.csv
#     ✓ Verified: File exists (8.53 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-28
#     URL: https://data.insideairbnb.com/italy/lombardia/bergamo/2025-06-28/data/listings.csv.gz
#     ⏳ Waiting 4.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.8 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bergamo.csv
#     📊 File size: 7.66 MB
# ✅ Success: bergamo.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 3719 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4661209677700763354-17d726fa-656c-4375-8b3a-2f5c2a691f6a-89-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bergamo.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bergamo.csv
#     ✓ Verified: File exists (8.27 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-23
#     URL: https://data.insideairbnb.com/germany/be/berlin/2025-09-23/data/listings.csv.gz
#     ⏳ Waiting 5.7 seconds...
#     🌐 Sending request...
#     📦 Downloading file (6.9 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/berlin.csv
#     📊 File size: 29.20 MB
# ✅ Success: berlin.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 14274 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3390431858872117346-8ad5ce14-66ea-4b49-821a-624c48db4c29-97-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/berlin.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/berlin.csv
#     ✓ Verified: File exists (31.50 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-22
#     URL: https://data.insideairbnb.com/italy/emilia-romagna/bologna/2025-09-22/data/listings.csv.gz
#     ⏳ Waiting 5.8 seconds...
#     🌐 Sending request...
#     📦 Downloading file (2.3 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bologna.csv
#     📊 File size: 10.11 MB
# ✅ Success: bologna.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 4642 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-8520679684919402951-ac195cee-1ecf-4b25-a90f-f6716d8a0633-105-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bologna.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bologna.csv
#     ✓ Verified: File exists (10.84 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-15
#     URL: https://data.insideairbnb.com/france/nouvelle-aquitaine/bordeaux/2025-06-15/data/listings.csv.gz
#     ⏳ Waiting 4.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (5.9 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bordeaux.csv
#     📊 File size: 23.89 MB
# ✅ Success: bordeaux.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 12383 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-2955184081337263114-7b5644b2-2b3c-4cac-83bb-fdcb70e8ae07-113-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bordeaux.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bordeaux.csv
#     ✓ Verified: File exists (25.88 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-23
#     URL: https://data.insideairbnb.com/united-states/ma/boston/2025-09-23/data/listings.csv.gz
#     ⏳ Waiting 5.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (2.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/boston.csv
#     📊 File size: 10.68 MB
# ✅ Success: boston.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 4419 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-6238787867877989181-bf944acc-028f-4ef3-91e1-a26aa6511686-121-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/boston.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/boston.csv
#     ✓ Verified: File exists (11.40 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-17
#     URL: https://data.insideairbnb.com/united-states/mt/bozeman/2025-10-17/data/listings.csv.gz
#     ⏳ Waiting 5.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.3 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bozeman.csv
#     📊 File size: 1.42 MB
# ✅ Success: bozeman.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 580 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7588502618651892813-22c28049-ed06-408a-ba33-679fe0f6e0b5-129-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bozeman.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bozeman.csv
#     ✓ Verified: File exists (1.52 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-07
#     URL: https://data.insideairbnb.com/australia/qld/brisbane/2025-10-07/data/listings.csv.gz
#     ⏳ Waiting 3.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.5 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/brisbane.csv
#     📊 File size: 14.63 MB
# ✅ Success: brisbane.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 6072 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3984262118017554181-67f54375-eaed-4168-bf52-6e37ec568004-137-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/brisbane.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/brisbane.csv
#     ✓ Verified: File exists (15.64 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/united-kingdom/england/bristol/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 5.1 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.5 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/bristol.csv
#     📊 File size: 6.26 MB
# ✅ Success: bristol.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 2845 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4103831995229895280-594c2bb9-e699-4a85-8029-857a19b288ac-145-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bristol.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/bristol.csv
#     ✓ Verified: File exists (6.72 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/united-states/fl/broward-county/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 3.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (9.3 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/broward_county.csv
#     📊 File size: 41.99 MB
# ✅ Success: broward_county.csv
#     📊 Reading CSV with pandas...
# /home/spark-a2a45b4a-1ba9-462d-90c6-22/.ipykernel/2534/command-6159821325050266-1257879295:162: DtypeWarning: Columns (72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pd = pd.read_csv(local_output_path)
#     📈 Loaded 16822 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1352542649336607485-b732f505-955f-4d2a-bed0-ce6d72dcf718-153-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/broward_county.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/broward_county.csv
#     ✓ Verified: File exists (44.76 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-21
#     URL: https://data.insideairbnb.com/belgium/bru/brussels/2025-06-21/data/listings.csv.gz
#     ⏳ Waiting 3.4 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/brussels.csv
#     📊 File size: 12.86 MB
# ✅ Success: brussels.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 6721 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-6887182348283139522-43ed60f6-07f1-4562-9b59-c8358ba63f2a-161-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/brussels.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/brussels.csv
#     ✓ Verified: File exists (13.93 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-25
#     URL: https://data.insideairbnb.com/hungary/közép-magyarország/budapest/2025-09-25/data/listings.csv.gz
#     ⏳ Waiting 4.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (6.6 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/budapest.csv
#     📊 File size: 28.56 MB
# ✅ Success: budapest.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 12391 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3941043264359747849-72e9b472-a601-4b01-861a-a3925afc29d5-169-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/budapest.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/budapest.csv
#     ✓ Verified: File exists (30.60 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-01-29
#     URL: https://data.insideairbnb.com/argentina/ciudad-autónoma-de-buenos-aires/buenos-aires/2025-01-29/data/listings.csv.gz
#     ⏳ Waiting 5.8 seconds...
#     🌐 Sending request...
#     📦 Downloading file (18.8 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/buenos_aires.csv
#     📊 File size: 76.11 MB
# ✅ Success: buenos_aires.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 35172 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7748002081753328490-bc165994-4542-4938-8e8d-901b868f2b2f-177-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/buenos_aires.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/buenos_aires.csv
#     ✓ Verified: File exists (81.76 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-28
#     URL: https://data.insideairbnb.com/united-states/ma/cambridge/2025-09-28/data/listings.csv.gz
#     ⏳ Waiting 5.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.6 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/cambridge.csv
#     📊 File size: 3.23 MB
# ✅ Success: cambridge.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 1358 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4774957882512508224-0d843b5a-e103-4d43-9c3d-5fb3958df508-185-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/cambridge.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/cambridge.csv
#     ✓ Verified: File exists (3.44 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-28
#     URL: https://data.insideairbnb.com/south-africa/wc/cape-town/2025-09-28/data/listings.csv.gz
#     ⏳ Waiting 3.1 seconds...
#     🌐 Sending request...
#     📦 Downloading file (14.3 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/cape_town.csv
#     📊 File size: 59.41 MB
# ✅ Success: cape_town.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 26877 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-8880468027322645538-2dc17fbd-6fc6-4e97-b037-1c06a824b5a5-193-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/cape_town.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/cape_town.csv
#     ✓ Verified: File exists (63.85 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-17
#     URL: https://data.insideairbnb.com/united-states/il/chicago/2025-06-17/data/listings.csv.gz
#     ⏳ Waiting 4.1 seconds...
#     🌐 Sending request...
#     📦 Downloading file (4.8 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/chicago.csv
#     📊 File size: 21.86 MB
# ✅ Success: chicago.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 8604 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1970105846669525201-4fb45895-a43e-4dbc-a4b1-330f13ca3684-201-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/chicago.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/chicago.csv
#     ✓ Verified: File exists (23.23 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-23
#     URL: https://data.insideairbnb.com/united-states/nv/clark-county-nv/2025-09-23/data/listings.csv.gz
#     ⏳ Waiting 4.3 seconds...
#     🌐 Sending request...
#     📦 Downloading file (8.1 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/clark_county_nv.csv
#     📊 File size: 39.58 MB
# ✅ Success: clark_county_nv.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 17624 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1878789051426927768-b3213579-eac4-4bb8-92ac-a2ead717628e-209-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/clark_county_nv.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/clark_county_nv.csv
#     ✓ Verified: File exists (42.64 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/united-states/oh/columbus/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 4.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (1.6 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/columbus.csv
#     📊 File size: 7.31 MB
# ✅ Success: columbus.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 2877 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-2329565918371777606-e79c30ec-f995-490f-a37c-a35d5128dbbd-217-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/columbus.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/columbus.csv
#     ✓ Verified: File exists (7.79 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-27
#     URL: https://data.insideairbnb.com/denmark/hovedstaden/copenhagen/2025-06-27/data/listings.csv.gz
#     ⏳ Waiting 4.7 seconds...
#     🌐 Sending request...
#     📦 Downloading file (10.7 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/copenhagen.csv
#     📊 File size: 43.47 MB
# ✅ Success: copenhagen.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 22684 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4172436886808717021-baf92c62-fb10-4dde-8efb-2821fe85ae61-225-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/copenhagen.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/copenhagen.csv
#     ✓ Verified: File exists (47.22 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-28
#     URL: https://data.insideairbnb.com/greece/crete/crete/2025-09-28/data/listings.csv.gz
#     ⏳ Waiting 3.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (15.9 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/crete.csv
#     📊 File size: 68.66 MB
# ✅ Success: crete.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 27582 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7789355143904189833-8fe3517a-2436-4e42-a20d-cdff33ee9b7f-233-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/crete.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/crete.csv
#     ✓ Verified: File exists (73.16 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-08-19
#     URL: https://data.insideairbnb.com/united-states/tx/dallas/2025-08-19/data/listings.csv.gz
#     ⏳ Waiting 4.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/dallas.csv
#     📊 File size: 14.12 MB
# ✅ Success: dallas.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 5723 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-987771916511789126-81ad40b3-52d8-4fef-9abd-a61726610965-241-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/dallas.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/dallas.csv
#     ✓ Verified: File exists (15.04 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-29
#     URL: https://data.insideairbnb.com/united-states/co/denver/2025-09-29/data/listings.csv.gz
#     ⏳ Waiting 5.7 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/denver.csv
#     📊 File size: 12.52 MB
# ✅ Success: denver.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 4910 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-8099303407525425976-76b7f3a1-d882-4404-90fe-3e9ac1648eeb-249-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/denver.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/denver.csv
#     ✓ Verified: File exists (13.33 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-16
#     URL: https://data.insideairbnb.com/ireland/leinster/dublin/2025-09-16/data/listings.csv.gz
#     ⏳ Waiting 5.8 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads
MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/girona.csv
#     📊 File size: 45.36 MB
# ✅ Success: girona.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 22456 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-5770389382766712819-c95d9dba-dc64-4af0-b488-b24b0234687e-313-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/girona.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/girona.csv
#     ✓ Verified: File exists (49.07 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-26
#     URL: https://data.insideairbnb.com/united-kingdom/england/greater-manchester/2025-09-26/data/listings.csv.gz
#     ⏳ Waiting 5.5 seconds...
#     🌐 Sending request...
# ...
#     ✓ Verified: File exists (10.90 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-27
#     URL: https://data.insideairbnb.com/japan/kantō/tokyo/2025-06-27/data/listings.csv.gz
#     ⏳ Waiting 3.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (15.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/tokyo.csv
#     📊 File size: 68.88 MB
# ✅ Success: tokyo.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 25297 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-6837196956585561686-32c5c336-3472-41a0-8e9d-8884e5e9c3e2-825-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/tokyo.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/tokyo.csv
#     ✓ Verified: File exists (72.99 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-07
#     URL: https://data.insideairbnb.com/canada/on/toronto/2025-10-07/data/listings.csv.gz
#     ⏳ Waiting 3.1 seconds...
#     🌐 Sending request...
#     📦 Downloading file (11.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/toronto.csv
#     📊 File size: 45.78 MB
# ✅ Success: toronto.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 21316 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3428327160067445927-bccd644d-bcda-48f1-aafa-104d9f51dd95-833-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/toronto.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/toronto.csv
#     ✓ Verified: File exists (49.28 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-29
#     URL: https://data.insideairbnb.com/italy/trentino-alto-adige-südtirol/trentino/2025-06-29/data/listings.csv.gz
#     ⏳ Waiting 3.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (4.2 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/trentino.csv
#     📊 File size: 17.85 MB
# ✅ Success: trentino.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 8919 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1555642883943938667-e0ab909a-f96a-4baf-8552-96c57cd63857-841-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/trentino.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/trentino.csv
#     ✓ Verified: File exists (19.34 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-21
#     URL: https://data.insideairbnb.com/united-states/mn/twin-cities-msa/2025-06-21/data/listings.csv.gz
#     ⏳ Waiting 4.4 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.1 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/twin_cities_msa.csv
#     📊 File size: 13.16 MB
# ✅ Success: twin_cities_msa.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 5298 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7753572998108913709-6459f8a0-e17f-4942-96b0-4f2d896d5e74-849-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/twin_cities_msa.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/twin_cities_msa.csv
#     ✓ Verified: File exists (14.04 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-23
#     URL: https://data.insideairbnb.com/spain/vc/valencia/2025-09-23/data/listings.csv.gz
#     ⏳ Waiting 4.2 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.8 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/valencia.csv
#     📊 File size: 16.60 MB
# ✅ Success: valencia.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 7844 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7866898631499896172-4098c66d-cc4f-4c3d-867b-25f4ba678044-857-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/valencia.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/valencia.csv
#     ✓ Verified: File exists (17.91 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-17
#     URL: https://data.insideairbnb.com/canada/bc/vancouver/2025-10-17/data/listings.csv.gz
#     ⏳ Waiting 3.4 seconds...
#     🌐 Sending request...
#     📦 Downloading file (2.7 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/vancouver.csv
#     📊 File size: 11.53 MB
# ✅ Success: vancouver.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 4705 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7435870094063391224-0d372879-f046-4992-8f2f-b66793549df1-865-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vancouver.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vancouver.csv
#     ✓ Verified: File exists (12.30 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-10-05
#     URL: https://data.insideairbnb.com/switzerland/vd/vaud/2025-10-05/data/listings.csv.gz
#     ⏳ Waiting 5.1 seconds...
#     🌐 Sending request...
#     📦 Downloading file (2.5 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/vaud.csv
#     📊 File size: 10.42 MB
# ✅ Success: vaud.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 5514 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3193225248084638459-6e09e397-2130-4227-a0e5-032a0a781a9d-873-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vaud.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vaud.csv
#     ✓ Verified: File exists (11.31 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-11
#     URL: https://data.insideairbnb.com/italy/veneto/venice/2025-09-11/data/listings.csv.gz
#     ⏳ Waiting 5.0 seconds...
#     🌐 Sending request...
#     📦 Downloading file (4.4 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/venice.csv
#     📊 File size: 18.46 MB
# ✅ Success: venice.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 8590 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-4977313691255734352-65068870-bc46-4c23-acb7-5ac1bf162b67-881-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/venice.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/venice.csv
#     ✓ Verified: File exists (19.87 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-29
#     URL: https://data.insideairbnb.com/canada/bc/victoria/2025-09-29/data/listings.csv.gz
#     ⏳ Waiting 4.4 seconds...
#     🌐 Sending request...
#     📦 Downloading file (2.0 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/victoria.csv
#     📊 File size: 8.46 MB
# ✅ Success: victoria.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 3396 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-1957496414854045025-4af2cac0-96d4-409c-bdf0-307fbae715d3-889-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/victoria.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/victoria.csv
#     ✓ Verified: File exists (9.01 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-09-14
#     URL: https://data.insideairbnb.com/austria/vienna/vienna/2025-09-14/data/listings.csv.gz
#     ⏳ Waiting 5.9 seconds...
#     🌐 Sending request...
#     📦 Downloading file (6.5 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/vienna.csv
#     📊 File size: 28.92 MB
# ✅ Success: vienna.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 14123 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-662700400883896209-e6e2dc7e-0ce2-4ca2-9a43-a9b5eaecb230-897-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vienna.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/vienna.csv
#     ✓ Verified: File exists (31.16 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-17
#     URL: https://data.insideairbnb.com/united-states/dc/washington-dc/2025-06-17/data/listings.csv.gz
#     ⏳ Waiting 4.5 seconds...
#     🌐 Sending request...
#     📦 Downloading file (3.7 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/washington_dc.csv
#     📊 File size: 16.46 MB
# ✅ Success: washington_dc.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 6423 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-6150090073887967532-a5165ba8-9367-4d2d-9398-47ccd52d609c-905-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/washington_dc.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/washington_dc.csv
#     ✓ Verified: File exists (17.50 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-23
#     URL: https://data.insideairbnb.com/australia/wa/western-australia/2025-06-23/data/listings.csv.gz
#     ⏳ Waiting 3.3 seconds...
#     🌐 Sending request...
#     📦 Downloading file (7.5 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/western_australia.csv
#     📊 File size: 30.07 MB
# ✅ Success: western_australia.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 12628 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-7299076316696707993-d0473805-7a94-4895-ac62-9666d3f0bffd-913-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/western_australia.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/western_australia.csv
#     ✓ Verified: File exists (32.29 MB)
#
# 📥 Downloading: listings.csv.gz
#     Date: 2025-06-15
#     URL: https://data.insideairbnb.com/canada/mb/winnipeg/2025-06-15/data/listings.csv.gz
#     ⏳ Waiting 4.6 seconds...
#     🌐 Sending request...
#     📦 Downloading file (0.8 MB)...
#     Progress: 100.0%
#     ✅ Download completed!
#     📦 Extracting file...
#     💾 Saved to: /tmp/airbnb_downloads/winnipeg.csv
#     📊 File size: 3.65 MB
# ✅ Success: winnipeg.csv
#     📊 Reading CSV with pandas...
#     📈 Loaded 1590 rows
#     ⚡ Converting to Spark DataFrame...
#     💾 Writing to temporary directory...
#     📦 Finding part file in temp directory...
#     ✅ Found: part-00000-tid-3860186927707490248-a302750a-15d6-4dc0-bab7-963600accd32-921-1-c000.csv
#     📋 Copying to final location: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data/winnipeg.csv
#     🗑️  Cleaning up temp directory...
#     ✅ Saved to: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data
#    • south_aegean.csv
#    • stockholm.csv
#    • sunshine_coast.csv
#    • sydney.csv
#    • taipei.csv
#    • tasmania.csv
#    • the_hague.csv
#    • thessaloniki.csv
#    • tokyo.csv
#    • toronto.csv
#    • trentino.csv
#    • twin_cities_msa.csv
#    • valencia.csv
#    • vancouver.csv
#    • vaud.csv
#    • venice.csv
#    • victoria.csv
#    • vienna.csv
#    • washington_dc.csv
#    • western_australia.csv
#    • winnipeg.csv
#    • zurich.csv
# ==================================================

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import col, udf, when
from pyspark.sql.types import StringType, DoubleType
import gender_guesser.detector as gender_detector

# Initialize gender detector
gd = gender_detector.Detector()
def predict_gender(name):
    if name is None or name == "NULL" or name == "" or name == "null":
        return "unknown"
    try:
        first_name = str(name).split()[0] if " " in str(name) else str(name)
        result = gd.get_gender(first_name)
        if result in ["male", "mostly_male"]:
            return "male"
        elif result in ["female", "mostly_female"]:
            return "female"
        else:
            return "unknown"
    except:
        return "unknown"
gender_udf = udf(predict_gender, StringType())

def safe_cast_to_double(value):
    if value is None or value == "NULL" or value == "null" or str(value).strip() == "":
        return 0.0
    try:
        cleaned = str(value).replace("$", "").replace(",", "")
        return float(cleaned)
    except:
        return 0.0
safe_cast_udf = udf(safe_cast_to_double, DoubleType())

INPUT_DIR = "abfss://airbnbdata@airbnbpro.dfs.core.windows.net/raw_data"
OUTPUT_DIR = "abfss://airbnbdata@airbnbpro.dfs.core.windows.net/cleaned_data_New"
OUTPUT_FILE = f"{OUTPUT_DIR}/airbnb_data.csv"

spark = SparkSession.builder.getOrCreate()
print("🏠 Airbnb Data Cleaning Pipeline")
print("=" * 60)

try:
    print("📥 Reading CSV files...")
    df_raw = (
        spark.read
        .option("header", "true")
        .option("escape", '"')
        .option("multiline", "true")
        .option("mode", "DROPMALFORMED")
        .csv(f"{INPUT_DIR}/*.csv")
    )
    print(f"📊 Found {len(df_raw.columns)} columns. Dropping text columns...")

    # === DROP PROBLEMATIC COLUMNS FIRST ===
    cols_to_drop = [
        "id",
        "scrape_id",
        "last_scraped",
        "source",
        "host_thumbnail_url",
        "host_picture_url",
        "host_verifications",
        "host_has_profile_pic",
        "neighbourhood",
        "neighbourhood_group_cleansed",
        "calendar_last_scraped",
        "calendar_updated",
        "license",
        "amenities"
    ]
    cols_to_drop_existing = [c for c in cols_to_drop if c in df_raw.columns]
    print(f"   Dropping columns: {cols_to_drop_existing}")
    df_cleaned = df_raw.drop(*cols_to_drop_existing)
    print(f"✅ Remaining columns: {len(df_cleaned.columns)}")

    # Now, continue with your cleaning pipeline
    if "host_name" in df_cleaned.columns:
        df_cleaned = df_cleaned.withColumn("gender", gender_udf(col("host_name")))
    else:
        df_cleaned = df_cleaned.withColumn("gender", F.lit("unknown"))

    if "name" in df_cleaned.columns:
        df_cleaned = df_cleaned.withColumn("name", when(
            (col("name").isNull()) | (col("name").isin("NULL", "null", "")),
            "Unknown Listing"
        ).otherwise(col("name")))

    if "price" in df_cleaned.columns:
        df_cleaned = df_cleaned.withColumn(
            "price_clean", F.regexp_replace(col("price"), "[$,]", "").cast(DoubleType())
        )
        df_cleaned = df_cleaned.withColumn(
            "price", when(col("price_clean").isNull(), 0.0).otherwise(col("price_clean"))
        ).drop("price_clean")

    if "has_availability" in df_cleaned.columns:
        df_cleaned = df_cleaned.withColumn(
            "has_availability",
            when(
                (col("has_availability").isNull()) | (col("has_availability").isin("NULL", "null")),
                "t"
            ).otherwise(col("has_availability"))
        )

    numeric_columns = [
        "availability_eoy", "estimated_occupancy_l365d", "number_of_reviews_ly",
        "review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness",
        "review_scores_checkin", "review_scores_communication", "review_scores_location",
        "review_scores_value"
    ]
    for column in numeric_columns:
        if column in df_cleaned.columns:
            df_cleaned = df_cleaned.withColumn(column, safe_cast_udf(col(column)))

    date_columns = ["first_review", "last_review"]
    for column in date_columns:
        if column in df_cleaned.columns:
            df_cleaned = df_cleaned.withColumn(column, when(
                (col(column).isNull()) | (col(column) == "NULL"),
                "2010-01-01"
            ).otherwise(col(column)))

    print("\n🧹 Step 5: Data cleaning summary...")
    final_count = df_cleaned.count()
    print(f"   Total rows: {final_count:,}")
    print(f"   Total columns: {len(df_cleaned.columns)}")

    df_cleaned.show(10, truncate=True)
    print(f"\n💾 Saving cleaned data to {OUTPUT_FILE}...")

    temp_dir = f"{OUTPUT_DIR}/temp_airbnb_data"
    df_cleaned.coalesce(1).write.mode("overwrite") \
        .option("header", True) \
        .option("quote", '"') \
        .option("escape", '"') \
        .option("quoteAll", True) \
        .csv(temp_dir)

    part_files = dbutils.fs.ls(temp_dir)
    csv_part_file = [f for f in part_files if f.name.startswith("part-") and f.name.endswith(".csv")]
    if csv_part_file:
        part_file = csv_part_file[0]
        dbutils.fs.cp(part_file.path, OUTPUT_FILE)
        dbutils.fs.rm(temp_dir, recurse=True)
        print(f"   ✓ Saved file: {OUTPUT_FILE}")
    else:
        print("❌ Error: No part file found after write.")

    print("\n✅ SUCCESS! Cleaned file saved, columns will not be shifted.")
    print("👉 Load with .option('multiline', 'true') when reading.")

except Exception as e:
    print(f"\n❌ Error: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🏠 Airbnb Data Cleaning Pipeline
# ============================================================
# 📥 Reading CSV files...
# 📊 Found 80 columns. Dropping text columns...
#    Dropping columns: ['id', 'scrape_id', 'last_scraped', 'source', 'host_thumbnail_url', 'host_picture_url', 'host_verifications', 'host_has_profile_pic', 'neighbourhood', 'neighbourhood_group_cleansed', 'calendar_last_scraped', 'calendar_updated', 'license', 'amenities']
# ✅ Remaining columns: 66
#
# 🧹 Step 5: Data cleaning summary...
#    Total rows: 1,502,741
#    Total columns: 67
# +--------------------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+------------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+-------------------+-------------------------+----------------------+----------------------+--------+---------+--------------------+---------------+------------+---------+--------------+--------+----+-----+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+---------------+---------------+---------------+----------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+------+-------+
# |         listing_url|                name|         description|neighborhood_overview|         picture_url|host_id|            host_url|   host_name|host_since|       host_location|          host_about|host_response_time|host_response_rate|host_acceptance_rate|host_is_superhost|  host_neighbourhood|host_listings_count|host_total_listings_count|host_identity_verified|neighbourhood_cleansed|latitude|longitude|       property_type|      room_type|accommodates|bathrooms|bathrooms_text|bedrooms|beds|price|minimum_nights|maximum_nights|minimum_minimum_nights|maximum_minimum_nights|minimum_maximum_nights|maximum_maximum_nights|minimum_nights_avg_ntm|maximum_nights_avg_ntm|has_availability|availability_30|availability_60|availability_90|availability_365|number_of_reviews|number_of_reviews_ltm|number_of_reviews_l30d|availability_eoy|number_of_reviews_ly|estimated_occupancy_l365d|estimated_revenue_l365d|first_review|last_review|review_scores_rating|review_scores_accuracy|review_scores_cleanliness|review_scores_checkin|review_scores_communication|review_scores_location|review_scores_value|instant_bookable|calculated_host_listings_count|calculated_host_listings_count_entire_homes|calculated_host_listings_count_private_rooms|calculated_host_listings_count_shared_rooms|reviews_per_month|  city| gender|
# +--------------------+--------------------+--------------------+---------------------+--------------------+-------+--------------------+------------+----------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+--------------------+-------------------+-------------------------+----------------------+----------------------+--------+---------+--------------------+---------------+------------+---------+--------------+--------+----+-----+--------------+--------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+---------------+---------------+---------------+----------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+------+-------+
# |https://www.airbn...|Holiday London DB...|My bright double ...| Finsbury Park is ...|https://a0.muscac...|  54730|https://www.airbn...|       Alina|2009-11-16|London, United Ki...|I am a Multi-Medi...|within a few hours|              100%|                 96%|                t|     LB of Islington|                2.0|                      5.0|                     t|             Islington|51.56861|  -0.1127|Private room in r...|   Private room|           1|      1.0| 1 shared bath|     1.0| 1.0| 70.0|             1|            29|                   1.0|                   1.0|                  29.0|                  29.0|                   1.0|                  29.0|               t|             21|             39|             69|             331|               55|                   10|                     1|            74.0|                 8.0|                     92.0|                 6440.0|  2010-08-18| 2025-08-21|                4.85|                   4.8|                      4.8|                 4.81|                       4.87|                  4.78|               4.78|               f|                             2|                                          1|                                           1|                                          0|              0.3|london| female|
# |https://www.airbn...|Bright Chelsea  A...|Lots of windows a...|       It is Chelsea.|https://a0.muscac...|  60302|https://www.airbn...|    Philippa|2009-12-05|Royal Borough of ...|English, grandmot...|              NULL|              NULL|                 50%|                f|             Chelsea|                1.0|                      1.0|                     t|  Kensington and Ch...| 51.4878| -0.16813|  Entire rental unit|Entire home/apt|           2|      1.0|        1 bath|     1.0| 1.0|149.0|             4|            30|                   4.0|                   4.0|                  30.0|                  30.0|                   4.0|                  30.0|               t|              0|              0|              0|             199|               97|                    1|                     0|             0.0|                 2.0|                      9.0|                 1341.0|  2009-12-21| 2025-04-05|                 4.8|                  4.86|                     4.87|                 4.88|                       4.84|                  4.93|               4.74|               f|                             1|                                          1|                                           0|                                          0|             0.51|london| female|
------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------+---------------+---------------+---------------+----------------+-----------------+---------------------+----------------------+----------------+--------------------+-------------------------+-----------------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-----------------+------+-------+
# only showing top 10 rows
#
# 💾 Saving cleaned data to abfss://airbnbdata@airbnbpro.dfs.core.windows.net/cleaned_data_New/airbnb_data.csv...
#    ✓ Saved file: abfss://airbnbdata@airbnbpro.dfs.core.windows.net/cleaned_data_New/airbnb_data.csv
#
# ✅ SUCCESS! Cleaned file saved, columns will not be shifted.
# 👉 Load with .option('multiline', 'true') when reading.

# %%
from pyspark.sql import SparkSession
import pandas as pd

spark = SparkSession.builder.getOrCreate()

# Read data
df = spark.read.option("header", "true").option("multiline", "true").csv(
    "abfss://airbnbdata@airbnbpro.dfs.core.windows.net/cleaned_data_New/*.csv"
)

# Convert to Pandas and display ALL columns
pdf = df.limit(50).toPandas()
display(pdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>listing_url</th><th>name</th><th>description</th><th>neighborhood_overview</th><th>picture_url</th><th>host_id</th><th>host_url</th><th>host_name</th><th>host_since</th><th>host_location</th><th>host_about</th><th>host_response_time</th><th>host_response_rate</th><th>host_acceptance_rate</th><th>host_is_superhost</th><th>host_neighbourhood</th><th>host_listings_count</th><th>host_total_listings_count</th><th>host_identity_verified</th><th>neighbourhood_cleansed</th><th>latitude</th><th>longitude</th><th>property_type</th><th>room_type</th><th>accommodates</th><th>bathrooms</th><th>bathrooms_text</th><th>bedrooms</th><th>beds</th><th>price</th><th>minimum_nights</th><th>maximum_nights</th><th>minimum_minimum_nights</th><th>maximum_minimum_nights</th><th>minimum_maximum_nights</th><th>maximum_maximum_nights</th><th>minimum_nights_avg_ntm</th><th>maximum_nights_avg_ntm</th><th>has_availability</th><th>availability_30</th><th>availability_60</th><th>availability_90</th><th>availability_365</th><th>number_of_reviews</th><th>number_of_reviews_ltm</th><th>number_of_reviews_l30d</th><th>availability_eoy</th><th>number_of_reviews_ly</th><th>estimated_occupancy_l365d</th><th>estimated_revenue_l365d</th><th>first_review</th><th>last_review</th><th>review_scores_rating</th><th>review_scores_accuracy</th><th>review_scores_cleanliness</th><th>review_scores_checkin</th><th>review_scores_communication</th><th>review_scores_location</th><th>review_scores_value</th><th>instant_bookable</th><th>calculated_host_listings_count</th><th>calculated_host_listings_count_entire_homes</th><th>calculated_host_listings_count_private_rooms</th><th>calculated_host_listings_count_shared_rooms</th><th>reviews_per_month</th><th>city</th><th>gender</th></tr></thead><tbody><tr><td>https://www.airbnb.com/rooms/13913</td><td>Holiday London DB Room Let-on going</td><td>My bright double bedroom with a large window has a relaxed feeling! It comfortably fits one or two and is centrally located just two blocks from Finsbury Park. Enjoy great restaurants in the area and easy access to easy transport tubes, trains and buses. Babies and children of all ages are welcome.</td><td>Finsbury Park is a friendly melting pot community composed of Turkish, French, Spanish, Middle Eastern, Irish and English families. <br />We have a wonderful variety of international restaurants directly under us on Stroud Green Road. And there are many shops and large Tescos supermarket right next door. <br /><br />But you can also venture up to Crouch End and along Greens Lanes where there will endless choice of Turkish and Middle Eastern cuisines.s</td><td>https://a0.muscache.com/pictures/miso/Hosting-13913/original/d755aa6d-cebb-4464-80be-2722c921e8d5.jpeg</td><td>54730</td><td>https://www.airbnb.com/users/show/54730</td><td>Alina</td><td>2009-11-16</td><td>London, United Kingdom</td><td>I am a Multi-Media Visual Artist and Creative Practitioner in Education. I live in  London England with a Greek/Canadian origins and work internationally.
#
supermarket is on Acre Lane, turn right out of the main gates,<br />continue across the main intersection with the town hall and tower, Tesco is on the left with a<br />large carpark out the front, approximately 10 minute walk.<br />Pharmacy<br />449 Brixton Road, Brixton SW9 8HH<br />There is a large Boots chemist at Brixton tube selling all the personal essentials. They also<br />have a pharmacy and trained medi</td><td>https://a0.muscache.com/pictures/miso/Hosting-73431/original/cbc4f342-33ec-4230-94ca-4095dc23e574.jpeg</td><td>383525</td><td>https://www.airbnb.com/users/show/383525</td><td>Emi</td><td>2011-02-09</td><td>London, United Kingdom</t ...

# %%
# %pip install gender_guesser
# Out:
# Collecting gender_guesser
#   Downloading gender_guesser-0.4.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Downloading gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
# Installing collected packages: gender_guesser
# Successfully installed gender_guesser-0.4.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
spark.conf.set(
    "fs.azure.sas.airbnbdata.airbnbpro.blob.core.windows.net",
    "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2025-11-29T01:58:38Z&st=2025-11-24T17:43:38Z&spr=https,http&sig=34nGgovEO3UkYSw0f5JoCafSGRWFO20cNXNZU4327Kk%3D"
)

# %%
spark.read.csv(
    "wasbs://airbnbdata@airbnbpro.blob.core.windows.net/cleaned_data_New/airbnb_data.csv",
    header=True,
    inferSchema=True,
    multiLine=True,
    escape='"'
)
# Make sure "fs.azure.sas.airbnbdata.airbnbpro.blob.core.windows.net" = "<YOUR_SAS_TOKEN>"
# is set in Spark configs!
# Out:
# DataFrame[listing_url: string, name: string, description: string, neighborhood_overview: string, picture_url: string, host_id: int, host_url: string, host_name: string, host_since: date, host_location: string, host_about: string, host_response_time: string, host_response_rate: string, host_acceptance_rate: string, host_is_superhost: string, host_neighbourhood: string, host_listings_count: double, host_total_listings_count: double, host_identity_verified: string, neighbourhood_cleansed: string, latitude: double, longitude: double, property_type: string, room_type: string, accommodates: int, bathrooms: double, bathrooms_text: string, bedrooms: double, beds: double, price: double, minimum_nights: int, maximum_nights: int, minimum_minimum_nights: double, maximum_minimum_nights: double, minimum_maximum_nights: double, maximum_maximum_nights: double, minimum_nights_avg_ntm: double, maximum_nights_avg_ntm: double, has_availability: string, availability_30: int, availability_60: int, availability_90: int, availability_365: int, number_of_reviews: int, number_of_reviews_ltm: int, number_of_reviews_l30d: int, availability_eoy: double, number_of_reviews_ly: double, estimated_occupancy_l365d: double, estimated_revenue_l365d: double, first_review: date, last_review: date, review_scores_rating: double, review_scores_accuracy: double, review_scores_cleanliness: double, review_scores_checkin: double, review_scores_communication: double, review_scores_location: double, review_scores_value: double, instant_bookable: string, calculated_host_listings_count: int, calculated_host_listings_count_entire_homes: int, calculated_host_listings_count_private_rooms: int, calculated_host_listings_count_shared_rooms: int, reviews_per_month: double, city: string, gender: string]

# %%
from flask import Flask, request, jsonify
import requests  # For calling Gemini API

app = Flask(__name__)

GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent"
GEMINI_API_KEY = "AIzaSyCtIqnFZFioIC6c4Ch-tCK5MOGENBlroTs"  # Set in Azure securely, never hard-coded in production

@app.route("/recommend", methods=["POST"])
def recommend():
    data = request.json
    gender = data.get("gender", "")
    city = data.get("city", "")
    age = data.get("age", "")
    hosts = data.get("hosts", "")

    prompt = (
        f"User profile:\n"
        f"Gender: {gender}\n"
        f"City: {city}\n"
        f"Age: {age}\n"
        f"Number of Hosts: {hosts}\n"
        "You are an expert Airbnb consultant. Give a personalized recommendation about how to best participate in Airbnb as a guest or host, tailored to this profile."
    )

    # Gemini API request payload
    gemini_payload = {
        "contents": [
            {"parts": [{"text": prompt}]}
        ]
    }

    gemini_response = requests.post(
        f"{GEMINI_API_URL}?key={GEMINI_API_KEY}",
        json=gemini_payload
    )

    if gemini_response.ok:
        output = gemini_response.json()
        # Gemini structure may differ; extract text wisely
        try:
            recommendation = output["candidates"][0]["content"]["parts"][0]["text"]
        except Exception:
            recommendation = output

        return jsonify({"recommendation": recommendation})
    else:
        return jsonify({"error": "Failed to get recommendation from Gemini"}), 500

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000, debug=True)  # Azure prefers 0.0.0.0
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# Traceback (most recent call last):
#   File "/databricks/python_shell/scripts/db_ipykernel_launcher.py", line 52, in <module>
#     main()
#   File "/databricks/python_shell/scripts/db_ipykernel_launcher.py", line 48, in main
#     DatabricksKernelApp.launch_instance(config=databricks_kernel_config())
#   File "/databricks/python/lib/python3.12/site-packages/traitlets/config/application.py", line 1074, in launch_instance
#     app.initialize(argv)
#   File "/databricks/python_shell/lib/dbruntime/app.py", line 41, in initialize
#     super().initialize(argv=argv)
#   File "/databricks/python_shell/lib/dbruntime/app.py", line 31, in initialize
#     super().initialize(argv=argv)
#   File "/databricks/python/lib/python3.12/site-packages/traitlets/config/application.py", line 118, in inner
#     return method(app, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 695, in initialize
#     self.write_connection_file()
#   File "/databricks/python/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 288, in write_connection_file
#     write_connection_file(cf, **connection_info)
#   File "/databricks/python/lib/python3.12/site-packages/jupyter_client/connect.py", line 156, in write_connection_file
#     with secure_write(fname) as f:
#   File "/usr/lib/python3.12/contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.12/site-packages/jupyter_core/paths.py", line 995, in secure_write
#     with os.fdopen(os.open(fname, open_flag, 0o0600), mode, encoding=encoding) as f:
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# PermissionError: [Errno 13] Permission denied: '/databricks/kernel-connections/1c2fb5dc23327f4517becf9998cda28303700403aeea586d20b664bb9b735ef1.json'
# /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3585: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
pip install dask dash
# Out:
# Requirement already satisfied: dask in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2a45b4a-1ba9-462d-90c6-2266efb2fffd/lib/python3.12/site-packages (2025.11.0)
# Collecting dash
#   Downloading dash-3.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: click>=8.1 in /databricks/python3/lib/python3.12/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /databricks/python3/lib/python3.12/site-packages (from dask) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /databricks/python3/lib/python3.12/site-packages (from dask) (2023.5.0)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from dask) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2a45b4a-1ba9-462d-90c6-2266efb2fffd/lib/python3.12/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /databricks/python3/lib/python3.12/site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2a45b4a-1ba9-462d-90c6-2266efb2fffd/lib/python3.12/site-packages (from dask) (1.1.0)
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /databricks/python3/lib/python3.12/site-packages (from dash) (6.6.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /databricks/python3/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash) (74.0.0)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /databricks/python3/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /databricks/python3/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: locket in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2a45b4a-1ba9-462d-90c6-2266efb2fffd/lib/python3.12/site-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests->dash) (2025.1.31)
# Downloading dash-3.3.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 17.3 MB/s eta 0:00:00
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: Werkzeug, retrying, itsdangerous, blinker, Flask, dash
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.7.0
#     Not uninstalling blinker at /usr/lib/python3/dist-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2a45b4a-1ba9-462d-90c6-2266efb2fffd
#     Can't uninstall 'blinker'. No files were found to uninstall.
# Successfully installed Flask-3.1.2 Werkzeug-3.1.3 blinker-1.9.0 dash-3.3.0 itsdangerous-2.2.0 retrying-1.4.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
